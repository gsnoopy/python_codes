# %%
import pandas as pd

# %% [markdown]
# # Arvores

# %%
fields = arcpy.ListFields("C:/Users/gust7439/Desktop/Vegetacao_Rios_2.gdb/Arvores")
Arvores = pd.DataFrame()

# %%
for field in fields:
    Arvores.insert (0, field.name, 0, allow_duplicates = False)

# %%
Arvores = Arvores.loc[:,::-1]
Arvores
# Out:
# Empty DataFrame
# Columns: [objectid, globalid, uniquerowid, nativa_exotica, especie_nao_identificada_info, especie, numero_perfilhos, pap_perfilhos, dap, pab, dab, coeficiente_de_rugosidade, altura_total, epifitos_arvore, caracteristicas, observacao_planta, parentrowid, created_date, created_user, last_edited_date, last_edited_user, aux, aux_1, aux_2]
# Index: []

# %%
fc = "C:/Users/gust7439/Desktop/Vegetacao_Rios_2.gdb/Arvores"

objectid = [row[0] for row in arcpy.da.SearchCursor(fc, "objectid")]
globalid = [row[0] for row in arcpy.da.SearchCursor(fc, "globalid")]
uniquerowid = [row[0] for row in arcpy.da.SearchCursor(fc, "uniquerowid")]
nativa_exotica = [row[0] for row in arcpy.da.SearchCursor(fc, "nativa_exotica")]
especie_nao_identificada_info = [row[0] for row in arcpy.da.SearchCursor(fc, "especie_nao_identificada_info")]
especie = [row[0] for row in arcpy.da.SearchCursor(fc, "especie")]
numero_perfilhos = [row[0] for row in arcpy.da.SearchCursor(fc, "numero_perfilhos")]
pap_perfilhos = [row[0] for row in arcpy.da.SearchCursor(fc, "pap_perfilhos")]
dap = [row[0] for row in arcpy.da.SearchCursor(fc, "dap")]
pab = [row[0] for row in arcpy.da.SearchCursor(fc, "pab")]
dab = [row[0] for row in arcpy.da.SearchCursor(fc, "dab")]
coeficiente_de_rugosidade = [row[0] for row in arcpy.da.SearchCursor(fc, "coeficiente_de_rugosidade")]
altura_total = [row[0] for row in arcpy.da.SearchCursor(fc, "altura_total")]
epifitos_arvore = [row[0] for row in arcpy.da.SearchCursor(fc, "epifitos_arvore")]
caracteristicas = [row[0] for row in arcpy.da.SearchCursor(fc, "caracteristicas")]
observacao_planta = [row[0] for row in arcpy.da.SearchCursor(fc, "observacao_planta")]
parentrowid = [row[0] for row in arcpy.da.SearchCursor(fc, "parentrowid")]
created_date = [row[0] for row in arcpy.da.SearchCursor(fc, "created_date")]
created_user = [row[0] for row in arcpy.da.SearchCursor(fc, "created_user")]
last_edited_date = [row[0] for row in arcpy.da.SearchCursor(fc, "last_edited_date")]
last_edited_user = [row[0] for row in arcpy.da.SearchCursor(fc, "last_edited_user")]
aux = [row[0] for row in arcpy.da.SearchCursor(fc, "aux")]
aux_1 = [row[0] for row in arcpy.da.SearchCursor(fc, "aux_1")]
aux_2 = [row[0] for row in arcpy.da.SearchCursor(fc, "aux_2")]

# %%
Arvores['objectid'] = objectid
Arvores['globalid']  = globalid
Arvores['uniquerowid'] = uniquerowid
Arvores['nativa_exotica'] = nativa_exotica
Arvores['especie_nao_identificada_info'] = especie_nao_identificada_info
Arvores['especie'] = especie
Arvores['numero_perfilhos'] = numero_perfilhos
Arvores['pap_perfilhos'] = pap_perfilhos
Arvores['dap'] = dap
Arvores['pab'] = pab
Arvores['dab'] = dab
Arvores['coeficiente_de_rugosidade'] = coeficiente_de_rugosidade
Arvores['altura_total'] = altura_total
Arvores['epifitos_arvore'] = epifitos_arvore
Arvores['caracteristicas'] = caracteristicas
Arvores['observacao_planta'] = observacao_planta
Arvores['parentrowid'] = parentrowid
Arvores['created_date'] = created_date
Arvores['created_user'] = created_user
Arvores['last_edited_date'] = last_edited_date
Arvores['last_edited_user'] = last_edited_user
Arvores['aux'] = aux
Arvores['aux_1'] = aux_1
Arvores['aux_2'] = aux_2

# %% [markdown]
# # Parcelas

# %%
fields = arcpy.ListFields("C:/Users/gust7439/Desktop/Vegetacao_Rios_2.gdb/Parcelas")
Parcelas = pd.DataFrame()

# %%
for field in fields:
    Parcelas.insert (0, field.name, 0, allow_duplicates = False)

# %%
Parcelas = Parcelas.loc[:,::-1]
Parcelas
# Out:
# Empty DataFrame
# Columns: [objectid, globalid, uniquerowid, parcela, classe_solos, hidromorfia, drenagem, declividade, parentrowid, created_date, created_user, last_edited_date, last_edited_user, aux, aux_1, aux_2]
# Index: []

# %%
fc = "C:/Users/gust7439/Desktop/Vegetacao_Rios_2.gdb/Parcelas"

# %%
objectid = [row[0] for row in arcpy.da.SearchCursor(fc, "objectid")]
globalid = [row[0] for row in arcpy.da.SearchCursor(fc, "globalid")]
uniquerowid = [row[0] for row in arcpy.da.SearchCursor(fc, "uniquerowid")]
parcela = [row[0] for row in arcpy.da.SearchCursor(fc, "parcela")]
classe_solos = [row[0] for row in arcpy.da.SearchCursor(fc, "classe_solos")]
hidromorfia = [row[0] for row in arcpy.da.SearchCursor(fc, "hidromorfia")]
drenagem = [row[0] for row in arcpy.da.SearchCursor(fc, "drenagem")]
declividade = [row[0] for row in arcpy.da.SearchCursor(fc, "declividade")]
parentrowid = [row[0] for row in arcpy.da.SearchCursor(fc, "parentrowid")]
created_date = [row[0] for row in arcpy.da.SearchCursor(fc, "created_date")]
created_user = [row[0] for row in arcpy.da.SearchCursor(fc, "created_user")]
last_edited_date = [row[0] for row in arcpy.da.SearchCursor(fc, "last_edited_date")]
last_edited_user = [row[0] for row in arcpy.da.SearchCursor(fc, "last_edited_user")]
aux = [row[0] for row in arcpy.da.SearchCursor(fc, "aux")]
aux_1 = [row[0] for row in arcpy.da.SearchCursor(fc, "aux_1")]
aux_2 = [row[0] for row in arcpy.da.SearchCursor(fc, "aux_2")]

# %%
Parcelas['objectid'] = objectid
Parcelas['globalid']  = globalid
Parcelas['uniquerowid'] = uniquerowid
Parcelas['parcela'] = parcela
Parcelas['classe_solos'] = classe_solos
Parcelas['hidromorfia'] = hidromorfia
Parcelas['drenagem'] = drenagem
Parcelas['declividade'] = declividade
Parcelas['parentrowid'] = parentrowid
Parcelas['created_date'] = created_date
Parcelas['created_user'] = created_user
Parcelas['last_edited_date'] = last_edited_date
Parcelas['last_edited_user'] = last_edited_user
Parcelas['aux'] = aux
Parcelas['aux_1'] = aux_1
Parcelas['aux_2'] = aux_2

# %% [markdown]
# # Vegetação

# %%
fields = arcpy.ListFields("C:/Users/gust7439/Desktop/Vegetacao_Rios_2.gdb/Vegetacao_Rios_2")
Vegetacao_Rios_2 = pd.DataFrame()

# %%
for field in fields:
    Vegetacao_Rios_2.insert (0, field.name, 0, allow_duplicates = False)

# %%
Vegetacao_Rios_2 = Vegetacao_Rios_2.loc[:,::-1]
Vegetacao_Rios_2
# Out:
# Empty DataFrame
# Columns: [objectid, globalid, uniquerowid, data_registro, responsaveis, municipio, pedossequencia, numero_ponto, codigo, carta, folha, altitude, personalizacao, provincia, nome_rio, largura_rio, composicao_leito, dinamica_rio, classificacao_margem, altura_margem, talude, composicao_margem, presenca_de, largura_vegetacao, presenca_estratos, presenca_cipos, epifitos_lista, serapilheira, estagio_sucessional, estagio_sucessional_outro, presenca_impactos, presenca_erosao, presenca_arvores_talude, coleta_solos, observacoes, shape, created_date, created_user, last_edited_date, last_edited_user, aux, aux_1, aux_2, parcela_1, parcela_2, parcela_3]
# Index: []

# %%
fc = "C:/Users/gust7439/Desktop/Vegetacao_Rios_2.gdb/Vegetacao_Rios_2"

objectid = [row[0] for row in arcpy.da.SearchCursor(fc, "objectid")]
globalid = [row[0] for row in arcpy.da.SearchCursor(fc, "globalid")]
uniquerowid = [row[0] for row in arcpy.da.SearchCursor(fc, "uniquerowid")]
data_registro = [row[0] for row in arcpy.da.SearchCursor(fc, "data_registro")]
responsaveis = [row[0] for row in arcpy.da.SearchCursor(fc, "responsaveis")]
municipio = [row[0] for row in arcpy.da.SearchCursor(fc, "municipio")]
pedossequencia = [row[0] for row in arcpy.da.SearchCursor(fc, "pedossequencia")]
numero_ponto = [row[0] for row in arcpy.da.SearchCursor(fc, "numero_ponto")]
codigo = [row[0] for row in arcpy.da.SearchCursor(fc, "codigo")]
carta = [row[0] for row in arcpy.da.SearchCursor(fc, "carta")]
folha = [row[0] for row in arcpy.da.SearchCursor(fc, "folha")]
altitude = [row[0] for row in arcpy.da.SearchCursor(fc, "altitude")]
personalizacao = [row[0] for row in arcpy.da.SearchCursor(fc, "personalizacao")]
provincia = [row[0] for row in arcpy.da.SearchCursor(fc, "provincia")]
nome_rio = [row[0] for row in arcpy.da.SearchCursor(fc, "nome_rio")]
largura_rio = [row[0] for row in arcpy.da.SearchCursor(fc, "largura_rio")]
composicao_leito = [row[0] for row in arcpy.da.SearchCursor(fc, "composicao_leito")]
dinamica_rio = [row[0] for row in arcpy.da.SearchCursor(fc, "dinamica_rio")]
classificacao_margem = [row[0] for row in arcpy.da.SearchCursor(fc, "classificacao_margem")]
altura_margem = [row[0] for row in arcpy.da.SearchCursor(fc, "altura_margem")]
talude = [row[0] for row in arcpy.da.SearchCursor(fc, "talude")]
composicao_margem = [row[0] for row in arcpy.da.SearchCursor(fc, "composicao_margem")]
presenca_de = [row[0] for row in arcpy.da.SearchCursor(fc, "presenca_de")]
largura_vegetacao = [row[0] for row in arcpy.da.SearchCursor(fc, "largura_vegetacao")]
presenca_estratos = [row[0] for row in arcpy.da.SearchCursor(fc, "presenca_estratos")]
presenca_cipos = [row[0] for row in arcpy.da.SearchCursor(fc, "presenca_cipos")]
epifitos_lista = [row[0] for row in arcpy.da.SearchCursor(fc, "epifitos_lista")]
serapilheira = [row[0] for row in arcpy.da.SearchCursor(fc, "serapilheira")]
estagio_sucessional = [row[0] for row in arcpy.da.SearchCursor(fc, "estagio_sucessional")]
estagio_sucessional_outro = [row[0] for row in arcpy.da.SearchCursor(fc, "estagio_sucessional_outro")]
presenca_impactos = [row[0] for row in arcpy.da.SearchCursor(fc, "presenca_impactos")]
presenca_erosao = [row[0] for row in arcpy.da.SearchCursor(fc, "presenca_erosao")]
presenca_arvores_talude = [row[0] for row in arcpy.da.SearchCursor(fc, "presenca_arvores_talude")]
coleta_solos = [row[0] for row in arcpy.da.SearchCursor(fc, "coleta_solos")]
observacoes = [row[0] for row in arcpy.da.SearchCursor(fc, "observacoes")]
shape = [row[0] for row in arcpy.da.SearchCursor(fc, "shape")]
created_date = [row[0] for row in arcpy.da.SearchCursor(fc, "created_date")]
created_user = [row[0] for row in arcpy.da.SearchCursor(fc, "created_user")]
last_edited_date = [row[0] for row in arcpy.da.SearchCursor(fc, "last_edited_date")]
last_edited_user = [row[0] for row in arcpy.da.SearchCursor(fc, "last_edited_user")]
aux = [row[0] for row in arcpy.da.SearchCursor(fc, "aux")]
aux_1 = [row[0] for row in arcpy.da.SearchCursor(fc, "aux_1")]
aux_2 = [row[0] for row in arcpy.da.SearchCursor(fc, "aux_2")]
parcela_1 = [row[0] for row in arcpy.da.SearchCursor(fc, "parcela_1")]
parcela_2 = [row[0] for row in arcpy.da.SearchCursor(fc, "parcela_2")]
parcela_3 = [row[0] for row in arcpy.da.SearchCursor(fc, "parcela_3")]

# %%
Vegetacao_Rios_2['objectid'] = objectid
Vegetacao_Rios_2['globalid'] = globalid
Vegetacao_Rios_2['uniquerowid'] = uniquerowid
Vegetacao_Rios_2['data_registro'] = data_registro
Vegetacao_Rios_2['responsaveis'] = responsaveis
Vegetacao_Rios_2['municipio'] = municipio
Vegetacao_Rios_2['pedossequencia'] = pedossequencia
Vegetacao_Rios_2['numero_ponto'] = numero_ponto
Vegetacao_Rios_2['codigo'] = codigo
Vegetacao_Rios_2['carta'] = carta
Vegetacao_Rios_2['folha'] = folha
Vegetacao_Rios_2['altitude'] = altitude
Vegetacao_Rios_2['personalizacao'] = personalizacao
Vegetacao_Rios_2['provincia'] = provincia
Vegetacao_Rios_2['nome_rio'] = nome_rio
Vegetacao_Rios_2['largura_rio'] = largura_rio
Vegetacao_Rios_2['composicao_leito'] = composicao_leito
Vegetacao_Rios_2['dinamica_rio'] = dinamica_rio
Vegetacao_Rios_2['classificacao_margem'] = classificacao_margem
Vegetacao_Rios_2['altura_margem'] = altura_margem
Vegetacao_Rios_2['talude'] = talude
Vegetacao_Rios_2['composicao_margem'] = composicao_margem
Vegetacao_Rios_2['presenca_de'] = presenca_de
Vegetacao_Rios_2['largura_vegetacao'] = largura_vegetacao
Vegetacao_Rios_2['presenca_estratos'] = presenca_estratos
Vegetacao_Rios_2['presenca_cipos'] = presenca_cipos
Vegetacao_Rios_2['epifitos_lista'] = epifitos_lista
Vegetacao_Rios_2['serapilheira'] = serapilheira
Vegetacao_Rios_2['estagio_sucessional'] = estagio_sucessional
Vegetacao_Rios_2['estagio_sucessional_outro'] = estagio_sucessional_outro
Vegetacao_Rios_2['presenca_impactos'] = presenca_impactos
Vegetacao_Rios_2['presenca_erosao'] = presenca_erosao
Vegetacao_Rios_2['presenca_arvores_talude'] = presenca_arvores_talude
Vegetacao_Rios_2['coleta_solos'] = coleta_solos
Vegetacao_Rios_2['observacoes'] = observacoes
Vegetacao_Rios_2['shape'] = shape
Vegetacao_Rios_2['created_date'] = created_date
Vegetacao_Rios_2['created_user'] = created_user
Vegetacao_Rios_2['last_edited_date'] = last_edited_date
Vegetacao_Rios_2['last_edited_user'] = last_edited_user
Vegetacao_Rios_2['aux'] = aux
Vegetacao_Rios_2['aux_1'] = aux_1
Vegetacao_Rios_2['aux_2'] = aux_2
Vegetacao_Rios_2['parcela_1'] = parcela_1
Vegetacao_Rios_2['parcela_2'] = parcela_2
Vegetacao_Rios_2['parcela_3'] = parcela_3

# %% [markdown]
# # Dataframes

# %%
Arvores.head(2)
# Out:
#    objectid  ... aux_2
# 0         1  ...  None
# 1         2  ...  None
#
# [2 rows x 24 columns]

# %%
Parcelas.head(2)
# Out:
#    objectid  ...                                              aux_2
# 0         1  ...  Parcela = 1; Classe de solos = LV; Hidromorfia...
# 1         2  ...  Parcela = 2; Classe de solos = CX; Hidromorfia...
#
# [2 rows x 16 columns]

# %%
Vegetacao_Rios_2.head(2)
# Out:
#    objectid  ...                                          parcela_3
# 0         1  ...  Parcela = 3; Classe de solos = LV; Hidromorfia...
# 1         2  ...  Parcela = 3; Classe de solos = LV; Hidromorfia...
#
# [2 rows x 46 columns]

# %% [markdown]
# # Checando tamanhos

# %%
Arvores.shape
# Out:
# (1474, 24)

# %%
Parcelas.shape
# Out:
# (98, 16)

# %%
Vegetacao_Rios_2.shape
# Out:
# (36, 46)

# %% [markdown]
# # Join

# %%
d_join = pd.merge(Vegetacao_Rios_2,Parcelas, left_on='uniquerowid', right_on='parentrowid', how = 'left')

# %%
d_join.head(2)
# Out:
#    objectid_x  ...                                            aux_2_y
# 0           1  ...  Parcela = 1; Classe de solos = LV; Hidromorfia...
# 1           1  ...  Parcela = 2; Classe de solos = CX; Hidromorfia...
#
# [2 rows x 62 columns]

# %%
d_join_final = pd.merge(d_join, Arvores, left_on='uniquerowid_y', right_on='parentrowid', how = 'left')

# %%
d_join_final.head(2)
# Out:
#    objectid_x  ... aux_2
# 0           1  ...  None
# 1           1  ...  None
#
# [2 rows x 86 columns]

# %%
d_join_final.shape
# Out:
# (1474, 86)

# %%
d_join_final.to_excel('JoinRios.xlsx', index=False)
